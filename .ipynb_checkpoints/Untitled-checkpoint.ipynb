# %%
import cv2

# %%
img=cv2.imread('img.jfif')

# %%
img.shape
# Out:
# (2666, 4000, 3)

# %%
print(img)
# Out:
# [[[62 51  0]
#   [62 51  0]
#   [63 52  0]
#   ...
#   [22 21  7]
#   [22 21  7]
#   [22 21  7]]
#
#  [[61 50  0]
#   [61 50  0]
#   [62 51  0]
#   ...
#   [21 20  6]
#   [21 20  6]
#   [21 20  6]]
#
#  [[61 50  0]
#   [61 50  0]
#   [62 51  0]
#   ...
#   [21 20  6]
#   [21 20  6]
#   [22 21  7]]
#
#  ...
#
#  [[92 80  2]
#   [91 79  1]
#   [90 78  0]
#   ...
#   [37 37 21]
#   [37 37 21]
#   [37 37 21]]
#
#  [[90 79  0]
#   [92 81  1]
#   [92 81  1]
#   ...
#   [36 36 20]
#   [38 38 22]
#   [35 35 19]]
#
#  [[90 79  0]
#   [92 81  1]
#   [92 81  1]
#   ...
#   [36 36 20]
#   [38 38 22]
#   [35 35 19]]]

# %%
img[0]
# Out:
# array([[62, 51,  0],
#        [62, 51,  0],
#        [63, 52,  0],
#        ...,
#        [22, 21,  7],
#        [22, 21,  7],
#        [22, 21,  7]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
while True:
    cv2.imshow('result',img)
    #27 - ASCII of Escape
    if cv2.waitKey(2) == 27:
        break
cv2.destroyAllWindows()
